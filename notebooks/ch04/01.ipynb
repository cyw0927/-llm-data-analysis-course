# %%
from pathlib import Path

# %%
def get_project_root():
    current = Path.cwd().resolve()
    project_root = current

    while True:
        if (current / "data").is_dir():
            project_root = current
            break
        current = current.parent

    return project_root


def get_data_dir():
    return get_project_root() / "data"

# %%
print("프로젝트 루트 위치 ;", get_project_root())
print("현재 프로젝트의 데이터 폴더:", get_data_dir())
# Out:
# 프로젝트 루트 위치 ; C:\dev\llm-data-analysis-course
# 현재 프로젝트의 데이터 폴더: C:\dev\llm-data-analysis-course\data

# %%
from course_utils.paths import (get_project_root, get_data_dir)

print("프로젝트 루트 위치 ;", get_project_root())
print("현재 프로젝트의 데이터 폴더:", get_data_dir())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from course_utils.paths import (get_project_root, get_data_dir)
#       2
#       3 print("프로젝트 루트 위치 ;", get_project_root())
#       4 print("현재 프로젝트의 데이터 폴더:", get_data_dir())
#
# ModuleNotFoundError: No module named 'course_utils'
